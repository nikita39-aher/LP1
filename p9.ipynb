# %%
text = """Text analytics is the process of deriving meaningful information from natural language text.
It involves tokenization, part-of-speech tagging, removing stopwords, stemming, lemmatization and TF-IDF."""

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')   # required in newer versions
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
tokens = word_tokenize(text)
print("Tokens:\n", tokens)
# Out:
# Tokens:
#  ['Text', 'analytics', 'is', 'the', 'process', 'of', 'deriving', 'meaningful', 'information', 'from', 'natural', 'language', 'text', '.', 'It', 'involves', 'tokenization', ',', 'part-of-speech', 'tagging', ',', 'removing', 'stopwords', ',', 'stemming', ',', 'lemmatization', 'and', 'TF-IDF', '.']

# %%
# !python -m nltk.downloader punkt
# !python -m nltk.downloader punkt_tab
# Out:
# <frozen runpy>:128: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <frozen runpy>:128: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
tokens = text.split()
print(tokens)
# Out:
# ['Text', 'analytics', 'is', 'the', 'process', 'of', 'deriving', 'meaningful', 'information', 'from', 'natural', 'language', 'text.', 'It', 'involves', 'tokenization,', 'part-of-speech', 'tagging,', 'removing', 'stopwords,', 'stemming,', 'lemmatization', 'and', 'TF-IDF.']
